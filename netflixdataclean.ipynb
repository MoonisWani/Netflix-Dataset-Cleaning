# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\mooni\\ProjectsVSC\\NetflixData\\netflixData.csv")

# %%
df.head()
# Out:
#                                 Show Id                          Title  \
# 0  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 1  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 2  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
# 3  c293788a-41f7-49a3-a7fc-005ea33bce2b              #FriendButMarried
# 4  0555e67e-f624-4a05-93e4-55c117d0056d            #FriendButMarried 2
#
#                                          Description  \
# 0  As a grisly virus rampages a city, a lone man ...
# 1  Through her diary, Anne Frank's story is retol...
# 2  This pawesome documentary explores how our fel...
# 3  Pining for his high school crush for years, a ...
# 4  As Ayu and Ditto finally transition from best ...
#
#                       Director  \
# 0                       Cho Il
# 1  Sabina Fedeli, Anna Migotto
# 2             Michael Margolis
# 3                Rako Prijanto
# 4                Rako Prijanto
#
# ...

# %%
x = ['Director']
for i in x:
    print(df[i])
# Out:
# 0                            Cho Il
# 1       Sabina Fedeli, Anna Migotto
# 2                  Michael Margolis
# 3                     Rako Prijanto
# 4                     Rako Prijanto
#                    ...
# 3602                    Josef Fares
# 3603                       Sam Dunn
# 3604              Ahmed Nader Galal
# 3605                  Hong-seon Kim
# 3606                  Young Jun Lee
# Name: Director, Length: 3607, dtype: object

# %%
top_directors = df.sort_values(by='Imdb Score', ascending=False)
print(top_directors[['Director','Imdb Score']])
# Out:
#                                                Director  Imdb Score
# 1663                                          Onur Ünlü         9.1
# 749   Alastair Fothergill, Jonnie Hughes, Keith Scholey         9.1
# 2088                                    Samir Al Asfory         9.0
# 483                                          Bo Burnham         9.0
# 1063                                      Yasuhiro Irie         9.0
# ...                                                 ...         ...
# 43                                           Matei Dima         1.9
# 709                        Patrick Durham, Paul G. Volk         1.9
# 1260                                         Sajid Khan         1.8
# 3289                             Stanley Menino D'Costa         1.7
# 148                                          S.A. Zaidi         1.3
#
# [3607 rows x 2 columns]

# %%
top_directors.head(3607)
# Out:
#                                    Show Id  \
# 1663  faecb7ec-9844-4a27-be14-9fdcacb5edfc
# 749   9d781eca-0cb0-4314-82f0-bbd590749bc0
# 2088  6e0d34db-b4b3-4e50-a2b7-0d2c653e613a
# 483   389c030d-59cf-4065-a3fd-71566493cb8d
# 1063  f04b1850-e6fc-4b74-99d9-cedfa75d8532
# ...                                    ...
# 43    551e2c27-ae54-4918-bb58-4a6e7f1010c3
# 709   1a7f4054-64b6-4bdc-bf87-f0075e7feebd
# 1260  c1876a2e-e7df-4298-9d7f-fee98ea783f2
# 3289  257e1e6c-c095-4f95-b1b5-fb4eb8a32f52
# 148   7812f6bf-d227-429d-8361-998ae8ca4919
#
#                                          Title  \
# 1663                          Leyla and Mecnun
# 749   David Attenborough: A Life on Our Planet
# 2088                            No Longer kids
# 483                         Bo Burnham: Inside
# 1063          Fullmetal Alchemist: Brotherhood
# ...                                        ...
# 43                                       5Gang
# 709                Cross: Rise of the Villains
# ...

# %%
top_directors['Director'].value_counts()
# Out:
# Director
# Raúl Campos, Jan Suter           18
# Marcus Raboy                     16
# Jay Karas                        14
# Cathy Garcia-Molina              12
# Youssef Chahine                  12
#                                  ..
# Yanyong Kuruaungkoul              1
# Mandla Dube                       1
# Mark Franchetti, Andrew Meier     1
# Buzz Kulik                        1
# S.A. Zaidi                        1
# Name: count, Length: 2813, dtype: int64

# %%
top3 = pd.DataFrame(top_directors['Director'].value_counts().head(3))

# %%
top3
# Out:
#                         count
# Director
# Raúl Campos, Jan Suter     18
# Marcus Raboy               16
# Jay Karas                  14

# %%
new1 = top_directors[top_directors['Director'] == "Raúl Campos, Jan Suter"]

# %%
new1.head(3)
# Out:
#                                    Show Id                              Title  \
# 1746  b9e442ad-58cb-478c-b36b-018cf508732d      Luciano Mellera: Infantiloide
# 2639  05c30c0a-78b9-4d07-a859-27f673f3ac61      Sofía Niño de Rivera: Exposed
# 3306  e9d9071e-b058-42d3-93fc-bdac1803817f  Todo lo que sería Lucas Lauriente
#
#                                             Description  \
# 1746  Argentina's Luciano Mellera emphasizes the hum...
# 2639  Self-deprecating comic Sofía Niño de Rivera pu...
# 3306  In his stand-up set, Argentine comic Lucas Lau...
#
#                     Director           Genres                  Cast  \
# 1746  Raúl Campos, Jan Suter  Stand-Up Comedy       Luciano Mellera
# 2639  Raúl Campos, Jan Suter  Stand-Up Comedy  Sofía Niño de Rivera
# 3306  Raúl Campos, Jan Suter  Stand-Up Comedy       Lucas Lauriente
#
#      Production Country  Release Year      Rating Duration  Imdb Score  \
# 1746          Argentina          2018       TV-14   66 min         8.2
# ...

# %%
ave1 = new1['Imdb Score'].head(3).sum()/3

# %%
ave1
# Out:
# 7.599999999999999

# %%
new2 = top_directors[top_directors['Director'] == "Marcus Raboy"]

# %%
new2.head(3)
# Out:
#                                    Show Id  \
# 2774  29a66105-efcd-4301-85e5-847c1493d854
# 2465  a6d06009-6907-471e-aedc-cb4d7ff05a7e
# 268   6f67a8ed-2f0f-4acb-b796-374ec54ee8d1
#
#                                              Title  \
# 2774         Taylor Tomlinson: Quarter-Life Crisis
# 2465                     Ryan Hamilton: Happy Face
# 268   Anthony Jeselnik: Fire in the Maternity Ward
#
#                                             Description      Director  \
# 2774  She's halfway through her 20s — and she's over...  Marcus Raboy
# 2465  Small-town import Ryan Hamilton charms New Yor...  Marcus Raboy
# 268   Forging his own comedic boundaries, Anthony Je...  Marcus Raboy
#
#                Genres              Cast Production Country  Release Year  \
# 2774  Stand-Up Comedy  Taylor Tomlinson      United States          2020
# 2465  Stand-Up Comedy     Ryan Hamilton      United States          2017
# 268   Stand-Up Comedy  Anthony Jeselnik      United States          2019
#
# ...

# %%
ave2 = new2['Imdb Score'].head(3).sum()/3

# %%
ave2
# Out:
# 7.3999999999999995

# %%
new3 = top_directors[top_directors['Director'] == "Jay Karas"]

# %%
new3.head(3)
# Out:
#                                    Show Id  \
# 439   c418d1c4-bcec-47af-bffe-edf65a999d8b
# 442   3872feb9-03fd-4909-879d-dd5a4adeb0ba
# 3315  b741be1a-1afb-4679-a082-6b795e8fe0b7
#
#                                        Title  \
# 439   Bill Burr: I'm Sorry You Feel That Way
# 442   Bill Burr: You People Are All the Same
# 3315                 Tom Segura: Disgraceful
#
#                                             Description   Director  \
# 439   Bill Burr escapes the zombie apocalypse, explo...  Jay Karas
# 442   Funnyman Bill Burr takes the stage to uncork a...  Jay Karas
# 3315  Tom Segura gives voice to the sordid thoughts ...  Jay Karas
#
#                Genres        Cast Production Country  Release Year  \
# 439   Stand-Up Comedy   Bill Burr      United States          2014
# 442   Stand-Up Comedy   Bill Burr      United States          2012
# 3315  Stand-Up Comedy  Tom Segura      United States          2018
#
#           Rating Duration  Imdb Score Content Type
# ...

# %%
ave3 = new3['Imdb Score'].head(3).sum()/3

# %%
ave3
# Out:
# 8.1

# %%
avedata = [
    {"Directors" : top3.index[0], "Average Imdb Score" : ave1},
    {"Directors" : top3.index[1], "Average Imdb Score" : ave2},
    {"Directors" : top3.index[2], "Average Imdb Score" : ave3}
]

# %%
avedf = pd.DataFrame(avedata)
avedf.sort_values(by='Average Imdb Score', ascending=False)
# Out:
#                 Directors  Average Imdb Score
# 2               Jay Karas                 8.1
# 0  Raúl Campos, Jan Suter                 7.6
# 1            Marcus Raboy                 7.4
